# %%
import httpx
from bs4 import BeautifulSoup
import pandas as pd
import logging
import os
# Out:
# C:\Users\anaph\AppData\Local\Temp\ipykernel_15284\3806999953.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Configuração do logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%d/%m/%Y %H:%M:%S'
)

logger = logging.getLogger(__name__)

# Diminuir o nível de log para o httpx e outros loggers de terceiros
logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("urllib3").setLevel(logging.WARNING)

# %%
# URL do site
url = "https://origin.cpc.ncep.noaa.gov/products/analysis_monitoring/ensostuff/ONI_v5.php"

def get_html(url: str):
    """
    Retorna o conteúdo HTML da página.
    
    Parâmetros:
        url (str): URL do site.
    
    Retorna:
        str: Conteúdo HTML da página.
    """

    logger.debug(f"Fazendo requisição para {url}")
    response = httpx.get(url)
    response.raise_for_status()
    logger.debug("Requisição bem sucedida")
    return response.text

def extract_table_data(html: str):
    """
    Extrai os dados da tabela HTML e retorna uma lista de listas.
    
    Parâmetros:
        html (str): Conteúdo HTML da página.

    Retorna:
        Lista de listas: Cada sublista contém os dados de uma linha da tabela.
    """

    logger.info("Extraindo os dados da tabela HTML")
    soup = BeautifulSoup(html, 'html.parser')
    table_rows = soup.find_all('tr')

    data = []
    for row in table_rows:
        cols = row.find_all('td')
        cols = [col.text.strip() for col in cols if col.text.strip()]
        if cols and cols[0].isdigit():
            data.append(cols)
        elif len(cols) == 1 and cols[0] == "Year":
            logger.debug("Ignorando linha repetida de década")
    logger.info("Dados da tabela extraídos com sucesso")
    return data

def create_dataframe(data):
    """
    Cria um DataFrame a partir dos dados extraídos.
    
    Parâmetros:
        data (List[List[str]]): Lista de listas com os dados da tabela.

    Retorna:
        pd.DataFrame: DataFrame com os dados.
    """

    logger.debug("Criando DataFrame a partir dos dados extraídos")
    columns = ["Year", "DJF", "JFM", "FMA", "MAM", "AMJ", "MJJ", "JJA", "JAS", "ASO", "SON", "OND", "NDJ"]
    df = pd.DataFrame(data, columns=columns)
    logger.debug("DataFrame criado com sucesso")
    return df

def calcular_media_mes(df, mes_colunas):
    """Calcula a média dos valores dos meses passados por ano."""

    logger.debug(f"Calculando a média para os meses: {mes_colunas}")
    return df[mes_colunas].astype(float).mean(axis=1)

def classificar_fenomeno(media):
    """Classifica o fenômeno El Niño ou La Niña."""

    if media > 0.5:
        if media >= 1.5:
            return 'El Niño', 'Forte'
        elif media >= 1.0:
            return 'El Niño', 'Moderado'
        else:
            return 'El Niño', 'Fraco'
    elif media < -0.5:
        if media <= -1.5:
            return 'La Niña', 'Forte'
        elif media <= -1.0:
            return 'La Niña', 'Moderado'
        else:
            return 'La Niña', 'Fraco'
    else:
        return 'Neutro', 'Neutro'

def obter_trimestres_para_mes(mes):
    """
    Mapeia o mês para os três trimestres correspondentes.
    """
    mapeamento = {
        'Janeiro': ['NDJ', 'DJF', 'JFM'],
        'Fevereiro': ['DJF', 'JFM', 'FMA'],
        'Março': ['JFM', 'FMA', 'MAM'],
        'Abril': ['FMA', 'MAM', 'AMJ'],
        'Maio': ['MAM', 'AMJ', 'MJJ'],
        'Junho': ['AMJ', 'MJJ', 'JJA'],
        'Julho': ['MJJ', 'JJA', 'JAS'],
        'Agosto': ['JJA', 'JAS', 'ASO'],
        'Setembro': ['JAS', 'ASO', 'SON'],
        'Outubro': ['ASO', 'SON', 'OND'],
        'Novembro': ['SON', 'OND', 'NDJ'],
        'Dezembro': ['OND', 'NDJ', 'DJF'],
    }
    return mapeamento[mes]

def analisar_ano(df):
    """
    Analisa os fenômenos El Niño e La Niña para todos os meses de cada ano.
    """
    logger.info("Analisando os fenômenos El Niño e La Niña por mês e ano")
    resultados = []
    
    # Itera por cada ano
    for index, row in df.iterrows():
        ano = row['Year']
        
        for mes in ['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 
                    'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro']:
            
            trimestres = obter_trimestres_para_mes(mes)
            
            # Calcula a média das anomalias para o mês com base nos trimestres
            media_mes = calcular_media_mes(df.iloc[index:index+1], trimestres).iloc[0]
            fenomeno, intensidade = classificar_fenomeno(media_mes)

            logger.info(f"Ano {ano}, Mês {mes}: Fenômeno {fenomeno}, Intensidade {intensidade}")
            
            # Salvando o resultado por ano e mês
            resultados.append([ano, mes, fenomeno, intensidade])
    
    # Criando o DataFrame final com Ano, Mês, Fenômeno e Intensidade
    df_resultados = pd.DataFrame(resultados, columns=['Ano', 'Mês', 'Fenômeno', 'Intensidade'])
    logger.info("Análise concluída")
    return df_resultados

def save_to_excel(df, folder_path, file_name):
    """Salva o DataFrame em um arquivo Excel em uma pasta específica."""
    os.makedirs(folder_path, exist_ok=True)  # Cria a pasta se não existir
    file_path = os.path.join(folder_path, file_name)  # Cria o caminho completo
    logger.info(f"Salvando resultados no arquivo {file_path}")
    df.to_excel(file_path, index=False)
    logger.info("Arquivo Excel salvo com sucesso")

# Função principal que orquestra todo o processo
def main(folder_path=r"C:\Users\anaph\OneDrive\Área de Trabalho\DadosMeteorologicos", excel_file="resultados_oni.xlsx"):
    """Script principal para extração e análise dos dados do ONI."""
    try:
        logger.info("Iniciando o processo de extração e análise")
        
        # Etapa 1: Requisição e extração dos dados
        html = get_html(url)
        table_data = extract_table_data(html)

        # Etapa 2: Criar DataFrame
        df = create_dataframe(table_data)

        # Etapa 3: Analisar e classificar os fenômenos
        df_resultados = analisar_ano(df)

        # Etapa 4: Salvar em Excel
        save_to_excel(df_resultados, folder_path, excel_file)
        logger.info("Processo concluído com sucesso")

    except Exception as e:
        logger.error(f"Erro durante a execução: {e}")

if __name__ == "__main__":
    main()  # Chama a função main com os parâmetros padrão
# Out:
# 08/10/2024 18:24:11 - INFO - Iniciando o processo de extração e análise
# 08/10/2024 18:24:11 - DEBUG - Fazendo requisição para https://origin.cpc.ncep.noaa.gov/products/analysis_monitoring/ensostuff/ONI_v5.php
# 08/10/2024 18:24:12 - DEBUG - connect_tcp.started host='origin.cpc.ncep.noaa.gov' port=443 local_address=None timeout=5.0 socket_options=None
# 08/10/2024 18:24:12 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000239732B1F40>
# 08/10/2024 18:24:12 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x000002397465DAD0> server_hostname='origin.cpc.ncep.noaa.gov' timeout=5.0
# 08/10/2024 18:24:12 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000023972C86330>
# 08/10/2024 18:24:12 - DEBUG - send_request_headers.started request=<Request [b'GET']>
# 08/10/2024 18:24:12 - DEBUG - send_request_headers.complete
# 08/10/2024 18:24:12 - DEBUG - send_request_body.started request=<Request [b'GET']>
# 08/10/2024 18:24:12 - DEBUG - send_request_body.complete
# 08/10/2024 18:24:12 - DEBUG - receive_response_headers.started request=<Request [b'GET']>
# 08/10/2024 18:24:13 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 08 Oct 2024 21:24:13 GMT'), (b'Server', b'Apache'), (b'X-Frame-Options', b'SAMEORIGIN'), (b'X-Content-Type-Options', b'nosniff'), (b'X-XSS-Protection', b'1; mode=block'), (b'Vary', b'Accept-Encoding'), (b'Content-Encoding', b'gzip'), (b'Content-Length', b'7401'), (b'Keep-Alive', b'timeout=300, max=100'), (b'Connection', b'Keep-Alive'), (b'Content-Type', b'text/html; charset=UTF-8'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubdomains; preload')])
# 08/10/2024 18:24:13 - DEBUG - receive_response_body.started request=<Request [b'GET']>
# 08/10/2024 18:24:13 - DEBUG - receive_response_body.complete
# 08/10/2024 18:24:13 - DEBUG - response_closed.started
# 08/10/2024 18:24:13 - DEBUG - response_closed.complete
# 08/10/2024 18:24:13 - DEBUG - close.started
# 08/10/2024 18:24:13 - DEBUG - close.complete
# 08/10/2024 18:24:13 - DEBUG - Requisição bem sucedida
# 08/10/2024 18:24:13 - INFO - Extraindo os dados da tabela HTML
# 08/10/2024 18:24:13 - INFO - Dados da tabela extraídos com sucesso
# 08/10/2024 18:24:13 - DEBUG - Criando DataFrame a partir dos dados extraídos
# 08/10/2024 18:24:13 - DEBUG - DataFrame criado com sucesso
# 08/10/2024 18:24:13 - INFO - Analisando os fenômenos El Niño e La Niña por mês e ano
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Janeiro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Fevereiro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Março: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Abril: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Maio: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1950, Mês Dezembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Julho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Agosto: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Setembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Outubro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Novembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1951, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1952, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Janeiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Fevereiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Março: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Maio: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Julho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Agosto: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Setembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Outubro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Novembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1953, Mês Dezembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1954, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Janeiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Março: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Abril: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Maio: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Setembro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Outubro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Novembro: Fenômeno La Niña, Intensidade Forte
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1955, Mês Dezembro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Janeiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Março: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Abril: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1956, Mês Dezembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Janeiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Maio: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Junho: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Julho: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Agosto: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Setembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Outubro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Novembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:13 - INFO - Ano 1957, Mês Dezembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:13 - INFO - Ano 1958, Mês Janeiro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:13 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Fevereiro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Março: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Maio: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Julho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1958, Mês Dezembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Fevereiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1959, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1960, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1961, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1962, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Julho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Agosto: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Setembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Outubro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Novembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1963, Mês Dezembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Fevereiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1964, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Julho: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Agosto: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Setembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Outubro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Novembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1965, Mês Dezembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Janeiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Fevereiro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Março: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1966, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1967, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Março: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Outubro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Novembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1968, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Janeiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Fevereiro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Março: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Maio: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Agosto: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Setembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Outubro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Novembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:14 - INFO - Ano 1969, Mês Dezembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:14 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:14 - INFO - Ano 1970, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:15 - INFO - Ano 1970, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Janeiro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Fevereiro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Março: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Abril: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Maio: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:15 - INFO - Ano 1971, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:15 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# ...
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:18 - INFO - Ano 2017, Mês Dezembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Março: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Outubro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:18 - INFO - Ano 2018, Mês Novembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:18 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2018, Mês Dezembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Janeiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Fevereiro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Março: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Maio: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2019, Mês Dezembro: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Outubro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Novembro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2020, Mês Dezembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Janeiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Março: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Abril: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Maio: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2021, Mês Dezembro: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Janeiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Fevereiro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Março: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Abril: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Maio: Fenômeno La Niña, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Junho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Julho: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Agosto: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Setembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Outubro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Novembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2022, Mês Dezembro: Fenômeno La Niña, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Janeiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Fevereiro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Março: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Abril: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Junho: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Julho: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Agosto: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Setembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Outubro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Novembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2023, Mês Dezembro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['NDJ', 'DJF', 'JFM']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Janeiro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['DJF', 'JFM', 'FMA']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Fevereiro: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JFM', 'FMA', 'MAM']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Março: Fenômeno El Niño, Intensidade Moderado
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['FMA', 'MAM', 'AMJ']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Abril: Fenômeno El Niño, Intensidade Fraco
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MAM', 'AMJ', 'MJJ']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Maio: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['AMJ', 'MJJ', 'JJA']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Junho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['MJJ', 'JJA', 'JAS']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Julho: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JJA', 'JAS', 'ASO']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Agosto: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['JAS', 'ASO', 'SON']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Setembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['ASO', 'SON', 'OND']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Outubro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['SON', 'OND', 'NDJ']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Novembro: Fenômeno Neutro, Intensidade Neutro
# 08/10/2024 18:24:19 - DEBUG - Calculando a média para os meses: ['OND', 'NDJ', 'DJF']
# 08/10/2024 18:24:19 - INFO - Ano 2024, Mês Dezembro: Fenômeno El Niño, Intensidade Forte
# 08/10/2024 18:24:19 - INFO - Análise concluída
# 08/10/2024 18:24:19 - INFO - Salvando resultados no arquivo C:\Users\anaph\OneDrive\Área de Trabalho\DadosMeteorologicos\resultados_oni.xlsx
# 08/10/2024 18:24:19 - INFO - Arquivo Excel salvo com sucesso
# 08/10/2024 18:24:19 - INFO - Processo concluído com sucesso
